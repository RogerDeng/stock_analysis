# %%
import pandas as pd
import requests
import numpy as np
from io import StringIO
import time
import datetime

# %%
from sqlalchemy import *
def connect_sql(database,echo):
    engine = create_engine("mysql+pymysql://gary:jack0705@localhost:3306/{}".format(database),echo=echo)
    return engine
engine = connect_sql('twse',False)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates

# %%
def y_m_generator(first_y, last_y):
    y_m = [(y,m) for y in range(first_y, last_y+1) for m in range(1, 13)]
    return y_m

# %%
text = '''select distinct B.INDUSTRY_NAME_1
    from SII_REV_201812 A
    left join TEJ_STOCK_DATA_BASIC B
    on A.ID = B.ID
    ;'''
np.array(pd.read_sql_query(text, con=engine)['INDUSTRY_NAME_1'])
# Out:
# array(['金屬基本', '資源回收', '建設', '不織布', '觀光遊樂區', '汽車組件', '租賃業', '仲介建經',
#        '塑膠製品', '其他紡織', '公用事業', '五金及家具', '工程承攬', '其他水泥', '印刷', '電視廣播',
#        '保全業', '其他', '光電/ IO', '鞋及旅行箱', '金屬製品', '機械業', '網路設備', '餐飲飯店',
#        '電子設備', '廣告業', '機車船製造', '水泥製造', '通訊設備', '貨運倉儲業', '半導體', '主機板',
#        '電子零組件', '其他電子', '資訊通路', 'PC系統', '消費性電子', '其他化學', '其他電製品', '橡膠原料',
#        '藥', '輕油製解', '有線電視', '軟體服務', '期貨', '證券', '百貨批發', '成衣', '金融控股',
#        '本國銀行', '旅行社', '海運', '營造', '家電製品', '樹脂', '醫療耗材', '石化', '生物科技',
#        '貿易業', '壽險業', '產險業', '票券公司', '陸運業', '空運業', '預拌混凝土', '電機製品', '汽車買賣',
#        '汽車製造', '橡膠', '輪胎', '造紙', '紙漿', '玻璃陶瓷', '清潔劑', '染料及顏料', '油脂飼料',
#        '電線', '自行車組件', '人纖', '染整', '棉紡', '毛紡', '物業管理', '飲料乳品', '其他食品',
#        '罐頭加工', None], dtype=object)

# %%
text = '''select A.*
    ,B.INDUSTRY_NAME_1
    ,B.INDUSTRY_NAME_2
    from SII_REV_201812 A
    left join TEJ_STOCK_DATA_BASIC B
    on A.ID = B.ID
    WHERE B.INDUSTRY_NAME_1 in ('期貨','壽險業','金融控股','證券','產險業')
    order by B.INDUSTRY_NAME_1
    ;'''
pd.read_sql_query(text, con=engine).drop('Remark',axis=1)
# Out:
#       ID  NAME  Sales_This_Month  Sales_Last_Month  Sales_Last_Year    MOM  \
# 0   2867  三商美邦          15530901          14255534         19068071   8.94
# 1   2823    中壽          32096983          29748235         21856585   7.89
# 2   6024   群益期            148768            182517           217739 -18.49
# 3   2852   第一保            479143            556146           459150 -13.84
# 4   2851   中再保           1214731           1181174          1104589   2.84
# 5   2850    新產           1072786           1244122          1148947 -13.77
# 6   2832    台產            377121            410674           414466  -8.17
# 7   2816  旺旺保險            643310            685697           585741  -6.18
# 8   6005   群益證            437119            476974           858903  -8.35
# 9   2855  統一證券            319119            197861           426627  61.28
# 10  5880   合庫金           4066079           3902184          4413850   4.20
# 11  2892  第一金控           4835009           4484074          4390036   7.82
# 12  2891   中信金          32210898          28544497         33614468  12.84
# 13  2890  永豐金控           2300555           2521982          2558085  -8.77
# 14  2889  國票金控            564337            424516           832829  32.93
# 15  2888   新光金          18925856          21316558         19869975 -11.21
# 16  2887  台新金控           2822395           3116821          3137425  -9.44
# 17  2886   兆豐金           5293676           4808906          4409313  10.08
# 18  2885   元大金           8390762           9083812          9863950  -7.62
# 19  2884  玉山金控           4093815           4076214          4083057   0.43
# 20  2883   開發金          20447556          21326447         16130968  -4.12
# 21  2882   國泰金          49577550          31598872         75651772  56.89
# 22  2881   富邦金          21552859          28599422         34411301 -24.63
# 23  2880   華南金           3545643           3523521          3409640   0.62
#
#       YOY  ACC_Sales_This_Year  ACC_Sales_Last_Year  ACC_YOY INDUSTRY_NAME_1  \
# 0  -18.55            167844196            184989401    -9.26             壽險業
# 1   46.85            338495113            255328334    32.57             壽險業
# 2  -31.67              2810672              2682259     4.78              期貨
# 3    4.35              6129390              5881343     4.21             產險業
# 4    9.97             14871535             14599949     1.86             產險業
# 5   -6.62             14749316             13958399     5.66             產險業
# 6   -9.01              4953632              5068774    -2.27             產險業
# 7    9.82              7707765              7216794     6.80             產險業
# 8  -49.10              7640097              9253766   -17.43              證券
# 9  -25.19              5774275              7270099   -20.57              證券
# 10  -7.87             46682607             46632232     0.10            金融控股
# 11  10.13             60230070             50795648    18.57            金融控股
# 12  -4.17            314351266            349763656   -10.12            金融控股
# 13 -10.06             32123769             32526258    -1.23            金融控股
# 14 -32.23              5536765              6352732   -12.84            金融控股
# 15  -4.75            255769781            239666358     6.71            金融控股
# 16 -10.04             39801678             37866564     5.11            金融控股
# 17  20.05             61633712             59660388     3.30            金融控股
# 18 -14.93            101349480             94058730     7.75            金融控股
# 19   0.26             49179653             45796181     7.38            金融控股
# 20  26.75            253213265             86350934   193.23            金融控股
# 21 -34.46            477025725            584453274   -18.38            金融控股
# 22 -37.36            411530153            405928612     1.37            金融控股
# 23   3.98             45927728             42200525     8.83            金融控股
#
#    INDUSTRY_NAME_2
# 0              壽險業
# 1              壽險業
# 2               期貨
# 3              產險業
# 4              產險業
# 5              產險業
# 6              產險業
# 7              產險業
# 8               證券
# 9               證券
# 10            金融控股
# 11            金融控股
# 12            金融控股
# 13            金融控股
# 14            金融控股
# 15            金融控股
# 16            金融控股
# 17            金融控股
# 18            金融控股
# 19            金融控股
# 20            金融控股
# 21            金融控股
# 22            金融控股
# 23            金融控股
